# %%
import os

# Tentukan path direktori yang berisi file-file yang ingin direname
directory = 'AmbilData8/'

# Iterasi melalui semua file dalam direktori
for i, filename in enumerate(os.listdir(directory), start=1):
    # Cek apakah filename adalah file (bukan direktori)
    if os.path.isfile(os.path.join(directory, filename)):
        # Buat nama baru dengan urutan sekuensial
        new_filename = '{:d}.jpg'.format(i)
        # Ubah nama file
        old_name = os.path.join(directory, filename)
        new_name = os.path.join(directory, new_filename)
        os.rename(old_name, new_name)
        print(f"File {old_name} berhasil diubah menjadi {new_name}.")
# Out:
# File AmbilData8/00001.jpg berhasil diubah menjadi AmbilData8/1.jpg.
# File AmbilData8/00002.jpg berhasil diubah menjadi AmbilData8/2.jpg.
# File AmbilData8/00003.jpg berhasil diubah menjadi AmbilData8/3.jpg.
# File AmbilData8/00004.jpg berhasil diubah menjadi AmbilData8/4.jpg.
# File AmbilData8/00005.jpg berhasil diubah menjadi AmbilData8/5.jpg.
# File AmbilData8/00006.jpg berhasil diubah menjadi AmbilData8/6.jpg.
# File AmbilData8/00007.jpg berhasil diubah menjadi AmbilData8/7.jpg.
# File AmbilData8/00008.jpg berhasil diubah menjadi AmbilData8/8.jpg.
# File AmbilData8/00009.jpg berhasil diubah menjadi AmbilData8/9.jpg.
# File AmbilData8/00010.jpg berhasil diubah menjadi AmbilData8/10.jpg.
# File AmbilData8/00011.jpg berhasil diubah menjadi AmbilData8/11.jpg.
# File AmbilData8/00012.jpg berhasil diubah menjadi AmbilData8/12.jpg.
# File AmbilData8/00013.jpg berhasil diubah menjadi AmbilData8/13.jpg.
# File AmbilData8/00014.jpg berhasil diubah menjadi AmbilData8/14.jpg.
# ...

# %%
import os

# Tentukan path direktori yang berisi file-file yang ingin direname
directory = 'AmbilDataCahayaFull1_2/'

# Mendapatkan daftar file dalam direktori dan mengurutkannya berdasarkan angka dalam nama file
files = sorted(os.listdir(directory), key=lambda x: int(x.split('.')[0]), reverse=True)

# Iterasi melalui semua file dalam direktori
for i, filename in enumerate(files, start=1):
    # Cek apakah filename adalah file (bukan direktori)
    if os.path.isfile(os.path.join(directory, filename)):
        # Ubah nama file
        old_name = os.path.join(directory, filename)
        new_name = os.path.join(directory, '{:05d}.jpg'.format(i))
        os.rename(old_name, new_name)
        print(f"File {old_name} berhasil diubah menjadi {new_name}.")
# Out:
# File AmbilDataCahayaFull1_2/00149.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00001.jpg.
# File AmbilDataCahayaFull1_2/00148.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00002.jpg.
# File AmbilDataCahayaFull1_2/00147.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00003.jpg.
# File AmbilDataCahayaFull1_2/00146.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00004.jpg.
# File AmbilDataCahayaFull1_2/00145.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00005.jpg.
# File AmbilDataCahayaFull1_2/00144.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00006.jpg.
# File AmbilDataCahayaFull1_2/00143.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00007.jpg.
# File AmbilDataCahayaFull1_2/00142.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00008.jpg.
# File AmbilDataCahayaFull1_2/00141.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00009.jpg.
# File AmbilDataCahayaFull1_2/00140.jpg berhasil diubah menjadi AmbilDataCahayaFull1_2/00010.jpg.
# ...
